# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
# Out:
# /home/sanskriti/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
result_path_dict = {
    'ETTh1-prob-M' : 'informer_ETTh1_ftM_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc3_ebtimeF_dtTrue_mxTrue_Exp_0',
    'ETTh2-prob-M' : 'informer_ETTh2_ftM_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_0',
    'ECL-prob-M'   : 'informer_ECL_ftM_sl96_ll96_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_0',
    'WTH-prob-M'   : 'informer_WTH_ftM_sl96_ll96_pl48_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_Exp_0',
    'ETTh1-prob-S' : '',
    'ECL-prob-S'   : '',
    'WTH-prob-S'   : '',
    'ETTh2-prob-S' : 'informer_ETTh2_ftS_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc3_ebtimeF_dtTrue_mxTrue_Exp_0',
    'ETTh1-full-M' : 'informer_ETTh1_ftM_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atfull_fc3_ebtimeF_dtTrue_mxTrue_Exp_0',
    'ETTh2-full-M' : 'informer_ETTh2_ftM_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_Exp_0',
    'ECL-full-M'   : '',
    'WTH-full-M'   : 'informer_WTH_ftM_sl96_ll96_pl48_dm512_nh8_el2_dl1_df2048_atfull_fc5_ebtimeF_dtTrue_mxTrue_Exp_0',
    'ETTh1-full-S' : '',
    'ETTh2-full-S' : '',
    'ECL-full-S'   : '',
    'WTH-full-S'   : '',
}

# %% [markdown]
# # Univariate

# %%
datasets = ['ETTh1', 'ETTh2', 'ECL', 'WTH']
attentions = ['prob', 'full']

dir_dict = {}
for key in result_path_dict:
    value = result_path_dict[key]
    if value == '':
        continue
    data, attn, var = key.split('-')
    if var=='S':
        dir_dict[key] = value

# %%
out_file_name = 'output.txt'
metric_file_name = 'metrics.npy'
pred_file_name = 'pred.npy'
true_file_name = 'true.npy'
metrics = ['MAE','MSE','RMSE','MAPE','MSPE']

# %% [markdown]
# ## Training and Testing output

# %%
for key in dir_dict:
    print('\n------------------' + key + '------------------')
    out_file = open(dir_dict[key] + '/' + out_file_name, 'r')
    print(out_file.read())
    out_file.close()
# Out:
# ------------------ETTh2-prob-S------------------
# Args in experiment:
# Namespace(model='informer', data='ETTh2', root_path='./data/ETT/', data_path='ETTh2.csv', features='S', target='OT', freq='h', checkpoints='./checkpoints/', seq_len=48, label_len=48, pred_len=24, enc_in=1, dec_in=1, c_out=1, d_model=512, n_heads=8, e_layers=2, d_layers=1, s_layers=[3, 2, 1], d_ff=2048, factor=3, padding=0, distil=True, dropout=0.05, attn='prob', embed='timeF', activation='gelu', output_attention=False, do_predict=False, mix=True, cols=None, num_workers=0, itr=5, train_epochs=6, batch_size=32, patience=3, learning_rate=0.0001, des='Exp', loss='mse', lradj='type1', use_amp=False, inverse=False, use_gpu=False, gpu=0, use_multi_gpu=False, devices='0,1,2,3', detail_freq='h')
# Use CPU
# >>>>>>>start training : informer_ETTh2_ftS_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc3_ebtimeF_dtTrue_mxTrue_Exp_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8569
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1944380
# 	speed: 0.6393s/iter; left time: 960.8533s
# 	iters: 200, epoch: 1 | loss: 0.1166416
# 	speed: 0.6408s/iter; left time: 899.0481s
# Epoch: 1 cost time: 171.16033506393433
# Epoch: 1, Steps: 267 | Train Loss: 0.1968027 Vali Loss: 0.1173156 Test Loss: 0.1266275
# Validation loss decreased (inf --> 0.117316).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.1033166
# 	speed: 1.4299s/iter; left time: 1767.3275s
# 	iters: 200, epoch: 2 | loss: 0.0931719
# 	speed: 0.6384s/iter; left time: 725.2697s
# Epoch: 2 cost time: 170.4105463027954
# Epoch: 2, Steps: 267 | Train Loss: 0.1161135 Vali Loss: 0.1104443 Test Loss: 0.0913907
# Validation loss decreased (0.117316 --> 0.110444).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.0864769
# 	speed: 1.4344s/iter; left time: 1389.9273s
# 	iters: 200, epoch: 3 | loss: 0.0920729
# 	speed: 0.6434s/iter; left time: 559.1354s
# Epoch: 3 cost time: 170.79059839248657
# Epoch: 3, Steps: 267 | Train Loss: 0.0944245 Vali Loss: 0.1065003 Test Loss: 0.0829740
# Validation loss decreased (0.110444 --> 0.106500).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 100, epoch: 4 | loss: 0.0819501
# 	speed: 1.4279s/iter; left time: 1002.3776s
# 	iters: 200, epoch: 4 | loss: 0.0864730
# 	speed: 0.6383s/iter; left time: 384.2862s
# Epoch: 4 cost time: 169.6063690185547
# Epoch: 4, Steps: 267 | Train Loss: 0.0837211 Vali Loss: 0.1091732 Test Loss: 0.0839984
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.25e-05
# 	iters: 100, epoch: 5 | loss: 0.0698076
# 	speed: 1.4346s/iter; left time: 624.0353s
# 	iters: 200, epoch: 5 | loss: 0.0596000
# 	speed: 0.6624s/iter; left time: 221.9154s
# Epoch: 5 cost time: 171.3956000804901
# Epoch: 5, Steps: 267 | Train Loss: 0.0768411 Vali Loss: 0.1054106 Test Loss: 0.0824757
# Validation loss decreased (0.106500 --> 0.105411).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 100, epoch: 6 | loss: 0.0759597
# 	speed: 1.4292s/iter; left time: 240.1034s
# 	iters: 200, epoch: 6 | loss: 0.0635934
# 	speed: 0.6406s/iter; left time: 43.5584s
# Epoch: 6 cost time: 171.09348559379578
# Epoch: 6, Steps: 267 | Train Loss: 0.0732969 Vali Loss: 0.1044430 Test Loss: 0.0797796
# Validation loss decreased (0.105411 --> 0.104443).  Saving model ...
# Updating learning rate to 3.125e-06
# >>>>>>>testing : informer_ETTh2_ftS_sl48_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc3_ebtimeF_dtTrue_mxTrue_Exp_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (89, 32, 24, 1) (89, 32, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:0.07975518703460693, mae:0.21412883698940277

# %% [markdown]
# ## Visualization

# %%
for key in dir_dict:

    dir = dir_dict[key]
    pred = np.load(dir + '/' + pred_file_name)
    true = np.load(dir + '/' + true_file_name)
    
    # Choose samples or time series for visualization
    sample_index = [0, 100, 500, 1000]

    # Extract the predicted and true values for the chosen sample
    pred_values = pred[sample_index].flatten()
    truth_values = true[sample_index].flatten()

    # Plot the predicted and true time series
    fig = plt.figure(figsize=(10, 6))
    fig.suptitle('Predicted vs True Time Series for {}'.format(key))
    plt.subplot(2, 1, 1)
    for i in range(len(sample_index)):
        sub = fig.add_subplot(2, 2, i+1)
        sub.plot(pred[sample_index[i]], label='Predicted', linestyle='dashed')
        sub.plot(true[sample_index[i]], label='True', linestyle='solid')
        sub.set_title('Sample {}'.format(sample_index[i]))
        sub.legend()
    fig.show()
# Out:
# /tmp/ipykernel_62578/338443489.py:24: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## Results

# %%
table_df = pd.DataFrame(columns=metrics, index=dir_dict.keys())


for key in dir_dict:
    dir = dir_dict[key]
    results = np.load(dir + '/' + metric_file_name)
    for i, metric in enumerate(metrics):
        table_df.loc[key, metric] = results[i]
    
print(table_df)
# Out:
#                    MAE       MSE     RMSE      MAPE       MSPE
# ETTh2-prob-S  0.214129  0.079755  0.28241  0.622387  21.503216
